# %% [markdown]
# # Exploratory Data Analysis (EDA) on Resumes & Jobs Dataset
#
# This notebook performs EDA to understand the distribution of skills, job categories, and text properties of our resumes dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import spacy

# %matplotlib inline
sns.set_style('whitegrid')

# %% [markdown]
# ## 1. Data Loading

# %%
# Load datasets (adjust paths as necessary)
# resumes_df = pd.read_csv('../datasets/resume_dataset.csv')
# jobs_df = pd.read_csv('../datasets/jobs_dataset.csv')

# print(resumes_df.head())
# print(resumes_df.info())

# %% [markdown]
# ## 2. Text Preprocessing & Skill Distribution

# %%
def clean_text(text):
    if not isinstance(text, str):
        return ''
    import re
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    return text.lower().strip()

# resumes_df['cleaned_text'] = resumes_df['Resume'].apply(clean_text)

# %% [markdown]
# ## 3. Visualizations

# %%
# plt.figure(figsize=(12, 6))
# sns.countplot(y='Category', data=resumes_df, order=resumes_df['Category'].value_counts().index)
# plt.title('Distribution of Resume Categories')
# plt.show()
